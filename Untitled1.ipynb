# %%
# Importing required libraries
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# Accessing the HTML content from webpage
url = "https://www.amazon.in/gp/bestsellers/books/"
response = requests.get(url)
if response.status_code == 200:
    print("Successfully connected to the website.")
else:
    print("Not connected to the website.")
# Out:
# Successfully connected to the website.

# %%
pip install html5lib
# Out:
# Requirement already satisfied: html5lib in /opt/anaconda3/lib/python3.9/site-packages (1.1)
# Requirement already satisfied: webencodings in /opt/anaconda3/lib/python3.9/site-packages (from html5lib) (0.5.1)
# Requirement already satisfied: six>=1.9 in /opt/anaconda3/lib/python3.9/site-packages (from html5lib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Parsing the HTML content
soup = BeautifulSoup(response.content, 'html5lib')

# %%
# Step 4: Searching and navigating through the parse tree
book_names, authors, images, ratings, customers_ratings, prices = [], [], [], [], [], []
table = soup.find('div', attrs={'class': 'p13n-gridRow _cDEzb_grid-row_3Cywl'})
if table is not None:
    for row in table.findAll('div', attrs={'class': 'zg-grid-general-faceout'}):
        book_name = row.img['alt']
        if book_name is not None:
            text = book_name
        else:
            text = "Unknown Product"
        book_names.append(text)
        author = row.find('a', attrs={'class': 'a-size-small a-link-child'})
        if author is not None:
            text = author.text
        else:
            author_span = row.find('span', attrs={'class': 'a-size-small a-color-base'})
            if author_span is not None:
                text = author_span.text
            else:
                text = "Unknown Author"
        authors.append(text)
        image = row.img['src']
        if image is not None:
            url = image
        else:
            url = "No Link"
        images.append(url)
        rating = row.find('span', attrs={'class': 'a-icon-alt'})
        if rating is not None:
            text = rating.text
        else:
            text = "-1"
        ratings.append(text)
        customer = row.find('div', attrs={'class': 'a-icon-row'})
        if customer is not None:
            customers_rated = customer.find('span', attrs={'class': 'a-size-small'})
            if customers_rated is not None:
                text = customers_rated.text
            else:
                text = "0"
                customers_ratings.append(text)
        else:
            text = "0"
        customers_ratings.append(text)
        price = row.find('span', attrs={'class': 'p13n-sc-price'})
        if price is not None:
            text = price.text
        else:
            text = "0.00"
        prices.append(text)

# %%
# Step 5: Creating Dataframe
column_names = ['Book Name', "Author", "Image Link", "Rating", "Customer Rating", "Price"]
books = pd.DataFrame(columns=column_names)
books['Book Name'] = book_names
books['Author'] = authors
books['Image Link'] = images
books['Rating'] = ratings
books['Customer Rating'] = customers_ratings
books['Price'] = prices
print(books)
# Out:
#                                             Book Name  \
# 0                             The Psychology of Money
# 1   Atomic Habits: the life-changing million-copy ...
# 2   BlackBook of English Vocabulary March 2023 by ...
# 3   Grandma's Bag of Stories: Collection of 20+ Il...
# 4   My First Library: Boxset of 10 Board Books for...
# 5   The Hidden Hindu: ScienceFiction meets Indian ...
# 6                                THE 48 LAWS OF POWER
# 7            Rich Dad Poor Dad: 25th Anniversary Edit
# 8   The Crooked Timber of New India : Essays on a ...
# 9   Energize Your Mind: Learn the Art of Mastering...
# 10                The Power of Your Subconscious Mind
# 11  Brain Activity Book for Kids - 200+ Activities...
# 12  Ikigai: The Japanese secret to a long and happ...
# 13  First Aid for the USMLE Step 1 2023, Thirty Th...
# 14  NCERT Objective Studies Kit for UPSC, State PS...
# 15  My First Mythology Tale (Illustrated) (Set of ...
# 16  My First Book of Pencil Control : Practice Pat...
# 17  Trading Chart Breakout Pattern & Candlestick P...
# 18                    Shrimad Bhagwat Geeta Yatharoop
# 19                 Don't Believe Everything You Think
# 20           Life's Amazing Secrets: How to find Bala
# 21  Concept of Physics by H.C Verma Part - I - Ses...
# 22  The Hidden Hindu (Hindi Translation of The Hid...
://images-eu.ssl-images-amazon.com/images...  4.6 out of 5 stars
# 20  https://images-eu.ssl-images-amazon.com/images...  4.6 out of 5 stars
# 21  https://images-eu.ssl-images-amazon.com/images...  4.6 out of 5 stars
# 22  https://images-eu.ssl-images-amazon.com/images...  4.4 out of 5 stars
# 23  https://images-eu.ssl-images-amazon.com/images...  4.3 out of 5 stars
# 24  https://images-eu.ssl-images-amazon.com/images...  4.6 out of 5 stars
# 25  https://images-eu.ssl-images-amazon.com/images...  4.5 out of 5 stars
# 26  https://images-eu.ssl-images-amazon.com/images...  4.5 out of 5 stars
# 27  https://images-eu.ssl-images-amazon.com/images...  4.4 out of 5 stars
# 28  https://images-eu.ssl-images-amazon.com/images...  4.5 out of 5 stars
# 29  https://images-eu.ssl-images-amazon.com/images...  4.5 out of 5 stars
# 30  https://images-eu.ssl-images-amazon.com/images...  4.4 out of 5 stars
# 31  https://images-eu.ssl-images-amazon.com/images...                  -1
# 32  https://images-eu.ssl-images-amazon.com/images...  4.5 out of 5 stars
# 33  https://images-eu.ssl-images-amazon.com/images...  4.7 out of 5 stars
# 34  https://images-eu.ssl-images-amazon.com/images...  4.5 out of 5 stars
# 35  https://images-eu.ssl-images-amazon.com/images...  4.6 out of 5 stars
# 36  https://images-eu.ssl-images-amazon.com/images...  4.5 out of 5 stars
# 37  https://images-eu.ssl-images-amazon.com/images...  4.2 out of 5 stars
# 38  https://images-eu.ssl-images-amazon.com/images...  4.4 out of 5 stars
# 39  https://images-eu.ssl-images-amazon.com/images...  4.3 out of 5 stars
# 40  https://images-eu.ssl-images-amazon.com/images...  4.4 out of 5 stars
# 41  https://images-eu.ssl-images-amazon.com/images...  4.3 out of 5 stars
# 42  https://images-eu.ssl-images-amazon.com/images...  4.5 out of 5 stars
# 43  https://images-eu.ssl-images-amazon.com/images...  4.3 out of 5 stars
# 44  https://images-eu.ssl-images-amazon.com/images...  4.6 out of 5 stars
# 45  https://images-eu.ssl-images-amazon.com/images...  4.8 out of 5 stars
# 46  https://images-eu.ssl-images-amazon.com/images...  3.9 out of 5 stars
# 47  https://images-eu.ssl-images-amazon.com/images...  4.6 out of 5 stars
# 48  https://images-eu.ssl-images-amazon.com/images...  4.5 out of 5 stars
# 49  https://images-eu.ssl-images-amazon.com/images...  4.3 out of 5 stars
#
#    Customer Rating    Price
# 0           49,359  ₹180.00
# 1           77,602  ₹416.00
# 2              383  ₹232.00
# 3           18,882  ₹162.00
# 4           69,392  ₹379.00
# 5            1,372  ₹162.00
# 6           16,266  ₹575.00
# 7           21,923  ₹413.00
# 8                1  ₹299.00
# 9            1,547  ₹112.00
# 10          74,063   ₹85.00
# 11           3,374   ₹85.00
# 12          47,705  ₹368.00
# 13             368  ₹999.00
# 14              50  ₹950.00
# 15           6,924  ₹179.00
# 16          24,277   ₹89.00
# 17           2,298  ₹200.00
# 18          15,864  ₹190.00
# 19             293  ₹209.00
# 20          21,504  ₹159.00
# 21          12,906  ₹380.00
# 22             167  ₹150.00
# 23           2,579  ₹199.00
# 24           8,638  ₹165.00
# 25              96  ₹288.00
# 26           1,113  ₹149.00
# 27           1,036  ₹459.00
# 28           4,380  ₹709.00
# 29          78,636  ₹169.00
# 30          11,055   ₹69.00
# 31               0  ₹330.00
# 32           3,228  ₹226.00
# 33         113,685  ₹277.00
# 34             485  ₹194.00
# 35             156  ₹222.00
# 36          22,764  ₹299.00
# 37             161  ₹105.00
# 38           4,832  ₹259.00
# 39           1,524  ₹364.00
# 40           3,201  ₹128.00
# 41              70  ₹639.00
# 42           4,297  ₹179.00
# 43              61  ₹499.00
# 44           6,009  ₹162.00
# 45           5,838  ₹529.00
# 46              68  ₹249.00
# 47          10,007  ₹374.00
# 48           1,275  ₹245.00
# 49           3,409   ₹99.00

# %%
# Step 6: Creating CSV file
csv_file_path = "/Users/prudhviraj/Desktop/restaurant/amazon_books_1.csv"
new_file = open(csv_file_path, "x")

# %%
# Step 7: Storing data in a created csv file
books.to_csv(csv_file_path)
