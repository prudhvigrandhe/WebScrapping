# %%
# Importing required libraries
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# Accessing the HTML content from webpage
url = "https://www.amazon.in/gp/bestsellers/books/"
response = requests.get(url)
if response.status_code == 200:
    print("Successfully connected to the website.")
else:
    print("Not connected to the website.")
# Out:
# Successfully connected to the website.

# %%
pip install html5lib
# Out:
# Requirement already satisfied: html5lib in /opt/anaconda3/lib/python3.9/site-packages (1.1)
# Requirement already satisfied: six>=1.9 in /opt/anaconda3/lib/python3.9/site-packages (from html5lib) (1.16.0)
# Requirement already satisfied: webencodings in /opt/anaconda3/lib/python3.9/site-packages (from html5lib) (0.5.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Parsing the HTML content
soup = BeautifulSoup(response.content, 'html5lib')

# %%
# Step 4: Searching and navigating through the parse tree
book_names, authors, images, ratings, customers_ratings, prices = [], [], [], [], [], []
table = soup.find('div', attrs={'class': 'p13n-gridRow _cDEzb_grid-row_3Cywl'})
if table is not None:
    for row in table.findAll('div', attrs={'class': 'zg-grid-general-faceout'}):
        book_name = row.img['alt']
        if book_name is not None:
            text = book_name
        else:
            text = "Unknown Product"
        book_names.append(text)
        author = row.find('a', attrs={'class': 'a-size-small a-link-child'})
        if author is not None:
            text = author.text
        else:
            author_span = row.find('span', attrs={'class': 'a-size-small a-color-base'})
            if author_span is not None:
                text = author_span.text
            else:
                text = "Unknown Author"
        authors.append(text)
        image = row.img['src']
        if image is not None:
            url = image
        else:
            url = "No Link"
        images.append(url)
        rating = row.find('span', attrs={'class': 'a-icon-alt'})
        if rating is not None:
            text = rating.text
        else:
            text = "-1"
        ratings.append(text)
        customer = row.find('div', attrs={'class': 'a-icon-row'})
        if customer is not None:
            customers_rated = customer.find('span', attrs={'class': 'a-size-small'})
            if customers_rated is not None:
                text = customers_rated.text
            else:
                text = "0"
                customers_ratings.append(text)
        else:
            text = "0"
        customers_ratings.append(text)
        price = row.find('span', attrs={'class': 'p13n-sc-price'})
        if price is not None:
            text = price.text
        else:
            text = "0.00"
        prices.append(text)

# %%
# Step 5: Creating Dataframe
column_names = ['Book Name', "Author", "Image Link", "Rating", "Customer Rating", "Price"]
books = pd.DataFrame(columns=column_names)
books['Book Name'] = book_names
books['Author'] = authors
books['Image Link'] = images
books['Rating'] = ratings
books['Customer Rating'] = customers_ratings
books['Price'] = prices
print(books)
# Out:
#                                             Book Name  \
# 0                             The Psychology of Money
# 1   Atomic Habits: the life-changing million-copy ...
# 2                                THE 48 LAWS OF POWER
# 3   Grandma's Bag of Stories: Collection of 20+ Il...
# 4   BlackBook of English Vocabulary March 2023 by ...
# 5   Ikigai: The Japanese secret to a long and happ...
# 6   My First Library: Boxset of 10 Board Books for...
# 7            Rich Dad Poor Dad: 25th Anniversary Edit
# 8                     Shrimad Bhagwat Geeta Yatharoop
# 9   Energize Your Mind: Learn the Art of Mastering...
# 10                The Power of Your Subconscious Mind
# 11  Brain Activity Book for Kids - 200+ Activities...
# 12  The Hidden Hindu: ScienceFiction meets Indian ...
# 13  First Aid for the USMLE Step 1 2023, Thirty Th...
# 14  The Crooked Timber of New India : Essays on a ...
# 15  Stock Market Crash Course | Stock Market | Pus...
# 16                       THE CONCISE 48 LAWS OF POWER
# 17  My First Mythology Tale (Illustrated) (Set of ...
# 18                 Don't Believe Everything You Think
# 19  My First Book of Pencil Control : Practice Pat...
# 20  NTA UGC NET /SET/JRF Paper 1, Teaching and Res...
# 21  Concept of Physics by H.C Verma Part - I - Ses...
# 22  All In One Class 10th Social Science for CBSE ...
# 23  The Hidden Hindu (Hindi Translation of The Hid...
# 24                     The Magic Of The Lost Temple**
# 25  SSC General Studies 6500 TCS MCQ chapter wise ...
https://images-eu.ssl-images-amazon.com/images...  4.5 out of 5 stars
# 21  https://images-eu.ssl-images-amazon.com/images...  4.6 out of 5 stars
# 22  https://images-eu.ssl-images-amazon.com/images...                  -1
# 23  https://images-eu.ssl-images-amazon.com/images...  4.4 out of 5 stars
# 24  https://images-eu.ssl-images-amazon.com/images...  4.6 out of 5 stars
# 25  https://images-eu.ssl-images-amazon.com/images...  4.2 out of 5 stars
# 26  https://images-eu.ssl-images-amazon.com/images...  4.6 out of 5 stars
# 27  https://images-eu.ssl-images-amazon.com/images...  4.3 out of 5 stars
# 28  https://images-eu.ssl-images-amazon.com/images...  4.3 out of 5 stars
# 29  https://images-eu.ssl-images-amazon.com/images...  4.4 out of 5 stars
# 30  https://images-eu.ssl-images-amazon.com/images...  4.3 out of 5 stars
# 31  https://images-eu.ssl-images-amazon.com/images...  4.5 out of 5 stars
# 32  https://images-eu.ssl-images-amazon.com/images...  4.4 out of 5 stars
# 33  https://images-eu.ssl-images-amazon.com/images...  4.5 out of 5 stars
# 34  https://images-eu.ssl-images-amazon.com/images...  4.5 out of 5 stars
# 35  https://images-eu.ssl-images-amazon.com/images...  4.5 out of 5 stars
# 36  https://images-eu.ssl-images-amazon.com/images...  4.2 out of 5 stars
# 37  https://images-eu.ssl-images-amazon.com/images...  4.1 out of 5 stars
# 38  https://images-eu.ssl-images-amazon.com/images...  4.4 out of 5 stars
# 39  https://images-eu.ssl-images-amazon.com/images...  4.0 out of 5 stars
# 40  https://images-eu.ssl-images-amazon.com/images...  4.5 out of 5 stars
# 41  https://images-eu.ssl-images-amazon.com/images...  4.5 out of 5 stars
# 42  https://images-eu.ssl-images-amazon.com/images...  4.8 out of 5 stars
# 43  https://images-eu.ssl-images-amazon.com/images...  4.2 out of 5 stars
# 44  https://images-eu.ssl-images-amazon.com/images...  4.9 out of 5 stars
# 45  https://images-eu.ssl-images-amazon.com/images...  4.3 out of 5 stars
# 46  https://images-eu.ssl-images-amazon.com/images...  4.5 out of 5 stars
# 47  https://images-eu.ssl-images-amazon.com/images...  4.6 out of 5 stars
# 48  https://images-eu.ssl-images-amazon.com/images...  4.5 out of 5 stars
# 49  https://images-eu.ssl-images-amazon.com/images...  4.6 out of 5 stars
#
#    Customer Rating    Price
# 0           49,262  ₹180.00
# 1           77,459  ₹525.00
# 2           16,228  ₹499.00
# 3           18,862  ₹162.00
# 4              360  ₹232.00
# 5           47,643  ₹357.00
# 6           69,302  ₹379.00
# 7           21,838  ₹384.00
# 8           15,829  ₹190.00
# 9            1,505  ₹165.00
# 10          73,964   ₹85.00
# 11           3,352   ₹80.00
# 12           1,355  ₹170.00
# 13             357  ₹600.00
# 14               0  ₹299.00
# 15              17  ₹190.00
# 16           4,819  ₹259.00
# 17           6,908  ₹193.00
# 18             284  ₹209.00
# 19          24,248   ₹89.00
# 20              84  ₹288.00
# 21          12,879  ₹379.00
# 22               0  ₹330.00
# 23             159  ₹150.00
# 24           8,626  ₹165.00
# 25              55  ₹499.00
# 26          21,465  ₹159.00
# 27           2,566  ₹199.00
# 28              64  ₹614.00
# 29          11,030   ₹69.00
# 30           1,503  ₹364.00
# 31           1,267  ₹245.00
# 32           1,042  ₹459.00
# 33          78,698  ₹169.00
# 34          22,741  ₹299.00
# 35           4,358  ₹709.00
# 36              65  ₹499.00
# 37           2,289  ₹199.00
# 38           3,193  ₹128.00
# 39               1  ₹375.00
# 40           3,225  ₹226.00
# 41           4,290  ₹179.00
# 42           5,829  ₹527.00
# 43             166  ₹299.00
# 44             425  ₹399.00
# 45           3,397   ₹98.00
# 46             145  ₹219.00
# 47           6,000  ₹162.00
# 48             474  ₹203.00
# 49           9,983  ₹374.00

# %%
# Step 6: Creating CSV file
csv_file_path = "/Users/prudhviraj/Desktop/restaurant/amazon_books.csv"
new_file = open(csv_file_path, "x")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# /var/folders/2n/16d077r97js17bl2ltt3tn1w0000gn/T/ipykernel_3188/3329053652.py in <module>
#       1 # Step 6: Creating CSV file
#       2 csv_file_path = "/Users/prudhviraj/Desktop/restaurant/amazon_books.csv"
# ----> 3 new_file = open(csv_file_path, "x")
#       4 # Step 7: Storing data in a created csv file
#       5 # books.to_csv(csv_file_path)
#
# FileExistsError: [Errno 17] File exists: '/Users/prudhviraj/Desktop/restaurant/amazon_books.csv'

# %%
# Step 7: Storing data in a created csv file
books.to_csv(csv_file_path)
